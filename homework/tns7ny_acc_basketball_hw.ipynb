# %%
import pandas as pd

# 1A
# Load data
acc_players_df = pd.read_csv('/content/acc_players-2324F.csv', header=1)

# 1B
# Display first 5 rows
print("ACC 2023-2024 Player Stats:")
acc_players_df.head()
# Out:
# ACC 2023-2024 Player Stats:
#    Rk         Player Class Pos          School   G   MP  TRB  AST  STL  ...  \
# 0   1   Amaree Abram    SO   G    Georgia Tech  10  108   17   11    1  ...
# 1   2   Sola Adebisi    FR   F   Florida State   7    9    1    1    0  ...
# 2   3  Prince Aligbe    SO   F  Boston College  35  651  119   21   15  ...
# 3   4     Abe Atiyeh    SR   G  Boston College   4    6    0    0    0  ...
# 4   5    Zack Austin    JR   F      Pittsburgh  33  746  137   29   32  ...
#
#    TOV  PF  PTS    FG%    2P%    3P%    FT%   PER   WS  BPM
# 0    9  10   34  0.262  0.318  0.200  0.615   4.1 -0.1 -6.4
# 1    1   1    2  0.500  0.500    NaN    NaN   3.5  0.0 -6.7
# 2   30  51  164  0.435  0.522  0.147  0.620   9.4  0.9 -1.3
# 3    1   0    3  0.333  0.000  1.000    NaN   1.1  0.0 -8.2
# 4   13  35  216  0.417  0.563  0.295  0.737  18.0  2.9  7.9
#
# [5 rows x 21 columns]

# %%
# 2A
# Calculate the total points scored by all players combined
total_points = acc_players_df['PTS'].sum()
print(f"Total Points Scored by All Players: {total_points}")
# Out:
# Total Points Scored by All Players: 38411

# %%
# 2B
# Find the name and their stats for the player who has played the most minutes (MP)
most_mins_player = acc_players_df.loc[acc_players_df['MP'].idxmax()]
print(f"Player with the Most Minutes Played: {most_mins_player['Player']} ({most_mins_player['MP']} minutes)")
most_mins_player
# Out:
# Player with the Most Minutes Played: Casey Morsell (1333 minutes)
# Rk                  136
# Player    Casey Morsell
# Class                SR
# Pos                   G
# School         NC State
# G                    41
# MP                 1333
# TRB                 114
# AST                  67
# STL                  46
# BLK                  19
# TOV                  38
# PF                   86
# PTS                 455
# FG%               0.406
# 2P%               0.478
# 3P%                0.27
# FT%               0.806
# PER                13.4
# WS                  3.2
# BPM                 2.5
# Name: 135, dtype: object

# %%
# 2C
# Identify the top 5 players in terms of total rebounds (TRB)
top_rebounds_players = acc_players_df[['Player', 'TRB']].sort_values(by='TRB', ascending=False).head(5)
print("Top 5 Players by Total Rebounds:")
top_rebounds_players
# Out:
# Top 5 Players by Total Rebounds:
#               Player  TRB
# 5      Armando Bacot  380
# 178  Ian Schieffelin  340
# 90   Harrison Ingram  327
# 44    Mohamed Diarra  311
# 149    Norchad Omier  309

# %%
# 3A
# Create a new DataFrame containing only players who played more than 500 minutes
players_over_500_mins = acc_players_df[acc_players_df['MP'] > 500]
print("Players who Played Over 500 Minutes:")
players_over_500_mins.head()
# Out:
# Players who Played Over 500 Minutes:
#    Rk         Player Class Pos          School   G    MP  TRB  AST  STL  ...  \
# 2   3  Prince Aligbe    SO   F  Boston College  35   651  119   21   15  ...
# 4   5    Zack Austin    JR   F      Pittsburgh  33   746  137   29   32  ...
# 5   6  Armando Bacot    SR   F  North Carolina  37  1123  380   56   22  ...
# 7   8  Reece Beekman    SR   G        Virginia  34  1114  124  212   68  ...
# 9  10     Chris Bell    SO   F        Syracuse  32   865   75   21   18  ...
#
#    TOV   PF  PTS    FG%    2P%    3P%    FT%   PER   WS   BPM
# 2   30   51  164  0.435  0.522  0.147  0.620   9.4  0.9  -1.3
# 4   13   35  216  0.417  0.563  0.295  0.737  18.0  2.9   7.9
# 5   60  100  538  0.540  0.544  0.400  0.781  24.6  6.1   8.9
# 7   70   43  486  0.443  0.487  0.310  0.754  23.4  4.9  10.5
# 9   26   58  384  0.434  0.459  0.420  0.842  14.9  2.2   3.3
#
# [5 rows x 21 columns]

# %%
# 3B
# From this filtered DataFrame, determine the player with the highest total assists (AST)
highest_assists_player = players_over_500_mins.loc[players_over_500_mins['AST'].idxmax()]
print(f"Player with the Highest Total Assists")
highest_assists_player
# Out:
# Player with the Highest Total Assists
# Rk                    8
# Player    Reece Beekman
# Class                SR
# Pos                   G
# School         Virginia
# G                    34
# MP                 1114
# TRB                 124
# AST                 212
# STL                  68
# BLK                  17
# TOV                  70
# PF                   43
# PTS                 486
# FG%               0.443
# 2P%               0.487
# 3P%                0.31
# FT%               0.754
# PER                23.4
# WS                  4.9
# BPM                10.5
# Name: 7, dtype: object

# %%
# 3C
# Who are the top 3 Assist Leads in the League?
top_assist_leads = acc_players_df[['Player', 'AST']].sort_values(by='AST', ascending=False).head(3)
print("Top 3 Assist Leads in the ACC:")
top_assist_leads

# This gives same output, but uses players_over_500_mins dataframe:
# top_assist_leads2 = players_over_500_mins[['Player', 'AST']].sort_values(by='AST', ascending=False).head(3)
# print("Top 3 Assist Leads in the ACC:")
# top_assist_leads2
# Out:
# Top 3 Assist Leads in the ACC:
#              Player  AST
# 7     Reece Beekman  212
# 215  Jaeden Zackery  152
# 21    Elliot Cadeau  150

# %%
# 3D
# Who are the top 3 Shot Blockers?
top_shot_blockers = acc_players_df[['Player', 'BLK']].sort_values(by='BLK', ascending=False).head(3)
print("Top 3 Shot Blockers in the ACC:")
top_shot_blockers

# This gives same output, but uses players_over_500_mins dataframe:
# top_shot_blockers2 = players_over_500_mins[['Player', 'BLK']].sort_values(by='BLK', ascending=False).head(3)
# print("Top 3 Shot Blockers in the ACC:")
# top_shot_blockers2
# Out:
# Top 3 Shot Blockers in the ACC:
#             Player  BLK
# 51       Ryan Dunn   77
# 157   Quinten Post   61
# 5    Armando Bacot   56

# %%
# 4A
# Group the players by School and calculate the total points scored by each school
school_points = acc_players_df.groupby('School')[['PTS']].sum().reset_index()
print("Total Points Scored by School:")
school_points.head()
# Out:
# Total Points Scored by School:
#            School   PTS
# 0  Boston College  2667
# 1         Clemson  2785
# 2            Duke  2830
# 3   Florida State  2526
# 4    Georgia Tech  2272

# %%
# 4B
# Group the players by School and calculate the total assists (AST) for each team
school_assists = acc_players_df.groupby('School')[['AST']].sum().reset_index()
print("Total Assists by School:")
school_assists.head()
# Out:
# Total Assists by School:
#            School  AST
# 0  Boston College  509
# 1         Clemson  533
# 2            Duke  551
# 3   Florida State  406
# 4    Georgia Tech  425

# %%
# 4C
# Sort the schools by total points scored and display the top 3 schools
top_3_schools = school_points.sort_values(by='PTS', ascending=False)
print("Top 3 Schools by Total Points Scored:")
top_3_schools.head(3)
# Out:
# Top 3 Schools by Total Points Scored:
#            School   PTS
# 7        NC State  3101
# 8  North Carolina  3032
# 2            Duke  2830

# %%
# 5A Bonus
# Create a bar chart showing the top 5 players by total points scored (PTS)

import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

top_5_players_PTS = acc_players_df[['Player', 'PTS']].sort_values(by='PTS', ascending=False).head(5)

plt.figure(figsize=(10, 6))
sns.barplot(x='PTS', y='Player', data=top_5_players_PTS)
plt.title('Top 5 Players by Total Points Scored (PTS)')
plt.xlabel('Total Points Scored (PTS)')
plt.ylabel('Player')
plt.tight_layout()
plt.show()

# %%
# 5B Bonuns
# Correlation: Investigate whether there is any correlation between a player's field goal
# percentage (FG%) and their win shares (WS). Provide a scatter plot and calculate the
# correlation coefficient

correlation_coefficient = acc_players_df['FG%'].corr(acc_players_df['WS'])
print(f"Correlation Coefficient between FG% and WS: {correlation_coefficient}")
# Out:
# Correlation Coefficient between FG% and WS: 0.4210663894199787

# %%
# 5B Bonus (continued)

plt.figure(figsize=(10, 6))
plt.scatter(acc_players_df['FG%'], acc_players_df['WS'])
plt.title('Relationship between FG% and WS')
plt.xlabel('Field Goal Percentage (FG%)')
plt.ylabel('Win Shares (WS)')
plt.grid(True)
plt.show()

# %% [markdown]
# *3 paragraph reflection:*
#
# * One skill I improved through this assignment is gaining a clearer understanding of the difference between Pandas DataFrames and typical text-based outputs. Initially, I was focused on outputting the data in a simple text format, but I later transitioned to using Pandas DataFrames to better align with the assignment’s instructions and goals. I definitely prefer the appearance and functionality of Pandas DataFrames, as they look much cleaner and more organized. Although I was initially hesitant to remove the first row of the original DataFrame, I realized that it was a crucial step in the data cleaning process, and would save me issues later on. Becoming more comfortable with Pandas and practicing data manipulation and cleaning made this assignment a valuable exercise. While I was already familiar with techniques like filtering and sorting, I appreciated the chance to refresh and refine my skills with these tools. I believe these skills will be highly useful in future data science projects, particularly during the Exploratory Data Analysis (EDA) phase. Understanding how to clean data and work with CSV files is extremely relevant to a wide range of data science tasks.
#
# * The most challenging aspect of this assignment for me was understanding the variables. Many of the variables were unfamiliar, so I had to rely on Google and ChatGPT searches to figure out the abbreviations. While some were intuitive, like PTS (points), STL (steals), and BLK (blocks), others were not as straightforward. Another difficulty I encountered, as I mentioned earlier, was deciding whether to remove the first row, which was originally a header. Typically, the first row contains important information, like column names, so removing it felt counterintuitive. However, in this case, it made the data messier, so I ultimately chose to exclude it. In general, though, I don't think that this was the *most* challenging assignment, and I appreciate the specific yet simple instructions that were given, as it made for a good review of the material discussed during lecture and from previous DS classes that I have taken.
#
# * By understanding the statistics extracted from this ACC basketball dataset, many fields and industries can leverage this information for their own benefit. One application is in healthcare, where data on player activity can be used to predict and prevent injuries. By analyzing patterns like minutes played, frequency of high-intensity movements, or past injury history, healthcare professionals can develop preventative strategies to optimize player health and performance. Additionally, merchandise creators and NIL (Name, Image, and Likeness) boards can use this data to gauge player popularity and create marketing campaigns tailored to promote high-performing or fan-favorite players. From a general sports perspective, teams can track their players’ progress and pinpoint areas of strength and weakness. Data can be used to develop training programs or game strategies, providing insights into player skills, struggles, and the team’s overall strategy against opponents. Team dynamics can also be analyzed by studying how players perform together—determining the most effective starting lineups and substitution patterns for optimal in-game performance. All of this highlights the broad potential of data science in sports. By performing simple tasks such as reading and cleaning CSV files, and applying a few lines of Pandas, Matplotlib, and Seaborn code, data scientists can uncover valuable insights.
